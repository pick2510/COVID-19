# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import re
plt.rcParams["figure.figsize"] = [16,9]

# %%
data = pd.read_csv("../csse_covid_19_data/csse_covid_19_time_series/time_series_19-covid-Confirmed.csv")

# %%
data.drop(["Province/State", "Lat", "Long"], axis =1, inplace=True)

# %%
columns = list(data.columns)
columns[0] = "Country"
data.columns = columns

# %%
data_grouped = data.groupby("Country").sum().T
data_grouped.columns
# Out:
# Index(['Afghanistan', 'Albania', 'Algeria', 'Andorra', 'Antigua and Barbuda',
#        'Argentina', 'Armenia', 'Aruba', 'Australia', 'Austria',
#        ...
#        'Turkey', 'US', 'Ukraine', 'United Arab Emirates', 'United Kingdom',
#        'Uruguay', 'Uzbekistan', 'Venezuela', 'Vietnam',
#        'occupied Palestinian territory'],
#       dtype='object', name='Country', length=156)

# %%
data_grouped[["France", "Japan", "Switzerland", "United Kingdom"]].plot()
plt.grid()

# %%
#re.findall("Ir",list(data_grouped.columns))
list(data_grouped.columns)
# Out:
# ['Afghanistan',
#  'Albania',
#  'Algeria',
#  'Andorra',
#  'Antigua and Barbuda',
#  'Argentina',
#  'Armenia',
#  'Aruba',
#  'Australia',
#  'Austria',
#  'Azerbaijan',
#  'Bahrain',
#  'Bangladesh',
#  'Belarus',
#  'Belgium',
#  'Benin',
#  'Bhutan',
#  'Bolivia',
#  'Bosnia and Herzegovina',
#  'Brazil',
#  'Brunei',
#  'Bulgaria',
#  'Burkina Faso',
#  'Cambodia',
#  'Cameroon',
#  'Canada',
#  'Central African Republic',
#  'Chile',
#  'China',
#  'Colombia',
#  'Congo (Brazzaville)',
#  'Congo (Kinshasa)',
#  'Costa Rica',
#  "Cote d'Ivoire",
#  'Croatia',
#  'Cruise Ship',
#  'Cuba',
#  'Cyprus',
#  'Czechia',
#  'Denmark',
#  'Dominican Republic',
#  'Ecuador',
#  'Egypt',
#  'Equatorial Guinea',
#  'Estonia',
#  'Eswatini',
#  'Ethiopia',
#  'Finland',
#  'France',
#  'French Guiana',
#  'Gabon',
#  'Georgia',
#  'Germany',
#  'Ghana',
#  'Greece',
#  'Greenland',
#  'Guadeloupe',
#  'Guam',
#  'Guatemala',
#  'Guernsey',
#  'Guinea',
#  'Guyana',
#  'Holy See',
# ...

# %%
ch = data_grouped[["Switzerland"]]
idx_ch = np.where(ch.Switzerland >= 100)

it = data_grouped[["Italy"]]
idx_it = np.where(it.Italy >= 100)

de = data_grouped[["Germany"]]
idx_de = np.where(de.Germany >= 100)

ir = data_grouped[["Iran"]]
idx_ir = np.where(ir.Iran >= 100)


ca = data_grouped[["Canada"]]
idx_ca = np.where(ca.Canada >= 100)

be = data_grouped[["Belgium"]]
idx_be = np.where(be.Belgium >= 100)

at = data_grouped[["Austria"]]
idx_at = np.where(at.Austria >= 100)


ko = data_grouped[["Korea, South"]]
idx_ko = np.where(ko["Korea, South"] >= 100)

# %%
plt.plot(it.Italy.values[idx_it], "o-",label="Italy")
plt.plot(ch.Switzerland.values[idx_ch],"o-", label="CH")
plt.plot(de.Germany.values[idx_de], "o-",  label="Germany")
plt.plot(ir.Iran.values[idx_ir], "o-", label="Iran")
plt.plot(ca.Canada.values[idx_ca],"o-", label="Canada")
plt.plot(be.Belgium.values[idx_be],"o-", label="Belgium")
plt.plot(at.Austria.values[idx_at], "o-", label="Austria")
plt.plot(ko["Korea, South"].values[idx_ko], "o-", label="South Korea")
plt.legend()
plt.yscale("log")
#plt.xlim([0,  len(idx_ch[0])])
#plt.ylim([0,4000])
plt.grid(which="both")
plt.xlabel("Days since cases > 100")
plt.ylabel("Cases")
plt.title("Cases in important Chair of Building Physics countries from t = 0 where cases > 100")
plt.tight_layout()
plt.savefig("cbp_cases_log.png")

# %%
plt.plot(it.Italy.values[idx_it], "o-",label="Italy")
plt.plot(ch.Switzerland.values[idx_ch],"o-", label="CH")
plt.plot(de.Germany.values[idx_de], "o-",  label="Germany")
plt.plot(ir.Iran.values[idx_ir], "o-", label="Iran")
plt.plot(ca.Canada.values[idx_ca],"o-", label="Canada")
plt.plot(be.Belgium.values[idx_be],"o-", label="Belgium")
plt.plot(at.Austria.values[idx_at], "o-", label="Austria")
plt.plot(ko["Korea, South"].values[idx_ko], "o-", label="South Korea")
plt.legend()
#plt.yscale("log")
plt.xlim([0,  len(idx_ch[0])])
plt.ylim([0,4000])
plt.grid(which="both")
plt.xlabel("Days since cases > 100")
plt.ylabel("Cases")
plt.title("Cases in important Chair of Building Physics countries from t = 0 where cases > 100")
plt.tight_layout()
plt.savefig("cbp_cases_non_log.png")

# %%
it = it[it.Italy>=3]

# %%
plt.plot(ch)
plt.plot(it)
plt.xlim([0,25])
# Out:
# (0, 25)
